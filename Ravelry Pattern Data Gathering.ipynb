# %% [markdown]
# As of this writing, Ravelry is a database cataloguing the details of <b>903,348</b> knitting, crochet, and other fiber art patterns. It's an amazing resource for crafters looking for inspiration for their next project, not to mention its myriad features from forums, to the creation of pattern queues, to yarn stash curation. This is a wealth of resources for any yarn-enthusiast, and we are very excited to be tapping this resource and trying to draw some conclusions from the data we gather.
#
# ---
#
# Before you begin, you will need to create a file called 'account.env' and copy/paste the below code into the file. Be sure to replace the placeholder values for the username and password with your own unique keys provided at https://www.ravelry.com/pro/developer. For this application, we are using the "Basic Auth, read only" level of access.
#
# <code># .env
# RAVELRY_USERNAME='Your Username'
# RAVELRY_PASSWORD='Your Password'</code>
#
# Once you have a file set up with your credentials, let's get started!

# %%
# settings.py
from dotenv import load_dotenv
load_dotenv()

# OR, explicitly providing path to '.env'
from pathlib import Path  # python3 only
env_path = 'account.env'
load_dotenv(dotenv_path=env_path)
# Out:
# True

# %%
import os
RAVELRY_USERNAME = os.getenv("RAVELRY_USERNAME")
RAVELRY_PASSWORD = os.getenv("RAVELRY_PASSWORD")

# %% [markdown]
# At this point, I actually did a quick print to confirm that all was well with importing my authentication keys for the site. If you need that comfort, too, just remove the commenting from the below two lines. That will let you double check that both variables are carrying the correct values at this point in your personal running of the code.

# %%
# print(RAVELRY_USERNAME)
# print(RAVELRY_PASSWORD)

# %%
import requests
import json
import pandas as pd

# %% [markdown]
# During initial planning, we had been thinking we would have to navigate page by page to gather pattern data. As it happens, the request has a page size parameter! As such, I upped our original plan from 560... to about 1% of Ravelry's total pattern database. We'll be requesting <b>over 9000</b> patterns.
#
# We'll still need to navigate this using page numbers, as doing a full request for 9000 patterns will time out (status 504). Doing 5 calls of 2000 each will net a bit over the 1% without being too cumbersome farther along.

# %%
url = "https://api.ravelry.com/patterns/search.json"
response1 = requests.get(url, params={"sort": "popularity", "page_size": 2000, "page": 1}, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))
response2 = requests.get(url, params={"sort": "popularity", "page_size": 2000, "page": 2}, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))
response3 = requests.get(url, params={"sort": "popularity", "page_size": 2000, "page": 3}, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))
response4 = requests.get(url, params={"sort": "popularity", "page_size": 2000, "page": 4}, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))
response5 = requests.get(url, params={"sort": "popularity", "page_size": 2000, "page": 5}, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))

# %%
print(response1)
print(response2)
print(response3)
print(response4)
print(response5)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %% [markdown]
# As long as you're seeing that sweet "<Response [200]>" you're golden. That means that your authentication has been successful and you made a connection.

# %%
patternData1 = response1.json()
patternData2 = response2.json()
patternData3 = response3.json()
patternData4 = response4.json()
patternData5 = response5.json()

# %%
len(patternData1['patterns'])
# Out:
# 2000

# %%
type(patternData1['patterns'])
# Out:
# list

# %%
type(patternData1['patterns'][0])
# Out:
# dict

# %%
patternData1['patterns'][0].keys()
# Out:
# dict_keys(['free', 'id', 'name', 'permalink', 'personal_attributes', 'first_photo', 'designer', 'pattern_author', 'pattern_sources'])

# %%
patternData1['patterns'][0]
# Out:
# {'free': True,
#  'id': 130787,
#  'name': "Hermione's Everyday Socks",
#  'permalink': 'hermiones-everyday-socks',
#  'personal_attributes': None,
#  'first_photo': {'id': 7278181,
#   'sort_order': 1,
#   'x_offset': -8,
#   'y_offset': -35,
#   'square_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404_s.jpg',
#   'medium_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404.jpg',
#   'thumbnail_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404_t.jpg',
#   'small_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404_m.jpg',
#   'medium2_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404.jpg',
#   'small2_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404_n.jpg',
#   'caption': None,
#   'caption_html': None,
#   'copyright_holder': None},
#  'designer': {'crochet_pattern_count': 1,
#   'favorites_count': 2106,
#   'id': 14789,
#   'knitting_pattern_count': 80,
#   'name': 'Erica Lueder',
#   'patterns_count': 81,
#   'permalink': 'erica-lueder',
#   'users': [{'id': 40158,
#     'username': 'Dreamsinfiber',
#     'tiny_photo_url': 'https://avatars-d.ravelrycache.com/Dreamsinfiber/20979999/hermione_ravatar_photo_tiny.jpg',
#     'small_photo_url': 'https://avatars-d.ravelrycache.com/Dreamsinfiber/20979999/hermione_ravatar_photo_small.jpg',
#     'photo_url': 'https://avatars-d.ravelrycache.com/Dreamsinfiber/20979999/hermione_ravatar_photo_large.jpg'}]},
#  'pattern_author': {'crochet_pattern_count': 1,
#   'favorites_count': 2106,
#   'id': 14789,
#   'knitting_pattern_count': 80,
#   'name': 'Erica Lueder',
#   'patterns_count': 81,
#   'permalink': 'erica-lueder',
#   'users': [{'id': 40158,
#     'username': 'Dreamsinfiber',
#     'tiny_photo_url': 'https://avatars-d.ravelrycache.com/Dreamsinfiber/20979999/hermione_ravatar_photo_tiny.jpg',
#     'small_photo_url': 'https://avatars-d.ravelrycache.com/Dreamsinfiber/20979999/hermione_ravatar_photo_small.jpg',
#     'photo_url': 'https://avatars-d.ravelrycache.com/Dreamsinfiber/20979999/hermione_ravatar_photo_large.jpg'}]},
#  'pattern_sources': [{'amazon_rating': None,
#    'amazon_reviews': None,
#    'amazon_sales_rank': None,
#    'amazon_updated_at': None,
#    'amazon_url': None,
#    'approved_patterns_count': 58,
#    'asin': '',
#    'author': 'Erica Lueder',
#    'author_pattern_author_id': 14789,
#    'author_surname': 'Lueder',
#    'book_binding': None,
#    'completed': False,
#    'created_at': '2012/10/31 13:47:56 -0400',
#    'designer_pending_patterns_count': 0,
#    'designer_users_count': 0,
#    'editorships_count': 0,
#    'favorites_count': 132,
#    'first_photo_id': None,
#    'flaggings_count': 0,
#    'fulfilled_by_ravelry': False,
#    'has_photo': False,
#    'id': 126892,
#    'isbn_13': '',
#    'issue': None,
#    'keywords': "Erica Lueder's Ravelry Store",
#    'label': None,
#    'large_image_url': None,
#    'last_pattern_edit': '2019/09/30 13:44:03 -0400',
#    'link_id': 209342,
#    'list_price': None,
#    'lock_version': 4,
#    'medium_image_url': None,
#    'name': 'Dreams in Fiber',
#    'out_of_print': False,
#    'pattern_source_type_id': 7,
#    'patterns_count': 77,
#    'pending_patterns_count': 19,
#    'periodical': False,
#    'permalink': 'dreams-in-fiber-2',
#    'photos_permitted': False,
#    'popularity': 0.0,
#    'popularity_rank': 2147483647,
#    'price': None,
#    'publication_date': None,
#    'publication_date_set': 0,
#    'publication_day_set': 0,
#    'publication_sort_order': None,
#    'publication_year': None,
#    'publisher_id': None,
#    'shelf_image_path': None,
#    'shelf_image_size': None,
#    'small_image_url': None,
#    'source_group_id': None,
#    'stickies_count': 0,
#    'store_id': 5092,
#    'updated_at': '2017/12/21 12:56:37 -0500',
#    'url': 'http://www.ravelry.com/stores/erica-lueder-designs',
#    'work_id': None,
#    'notes': '<a href="http://www.yuzlercedizi.com" title="tek parça izle" rel="dofollow">tek parça izle</a>\r\n'},
#   {'amazon_rating': None,
#    'amazon_reviews': None,
#    'amazon_sales_rank': None,
#    'amazon_updated_at': None,
#    'amazon_url': None,
#    'approved_patterns_count': 43,
#    'asin': '',
#    'author': 'Erica Lueder',
#    'author_pattern_author_id': 14789,
#    'author_surname': 'Lueder',
#    'book_binding': None,
#    'completed': False,
#    'created_at': '2008/07/19 08:48:17 -0400',
#    'designer_pending_patterns_count': 0,
#    'designer_users_count': 43,
#    'editorships_count': 1,
#    'favorites_count': 46,
#    'first_photo_id': None,
#    'flaggings_count': 0,
#    'fulfilled_by_ravelry': False,
#    'has_photo': False,
#    'id': 26083,
#    'isbn_13': None,
#    'issue': None,
#    'keywords': '',
#    'label': None,
#    'large_image_url': None,
#    'last_pattern_edit': '2019/09/30 13:43:06 -0400',
#    'link_id': 51128,
#    'list_price': None,
#    'lock_version': 6,
#    'medium_image_url': None,
#    'name': 'Dreams in Fiber Website',
#    'out_of_print': False,
#    'pattern_source_type_id': 3,
#    'patterns_count': 43,
#    'pending_patterns_count': 0,
#    'periodical': False,
#    'permalink': 'dreams-in-fiber-website',
#    'photos_permitted': False,
#    'popularity': 0.0,
#    'popularity_rank': 514,
#    'price': None,
#    'publication_date': None,
#    'publication_date_set': 0,
#    'publication_day_set': 0,
#    'publication_sort_order': None,
#    'publication_year': None,
#    'publisher_id': None,
#    'shelf_image_path': None,
#    'shelf_image_size': None,
#    'small_image_url': None,
#    'source_group_id': None,
#    'stickies_count': 0,
#    'store_id': None,
#    'updated_at': '2017/12/21 12:57:04 -0500',
#    'url': 'http://dreamsinfiber.blogspot.com/',
#    'work_id': None,
#    'notes': ''}]}

# %%
patternID = patternData1['patterns'][0]['id']

# %%
getTestURL = f"https://api.ravelry.com/patterns/{patternID}.json"
testresponse = requests.get(getTestURL, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))

# %%
testresponse
# Out:
# <Response [200]>

# %%
testData = testresponse.json()

# %%
testData['pattern'].keys()
# Out:
# dict_keys(['comments_count', 'created_at', 'currency', 'difficulty_average', 'difficulty_count', 'downloadable', 'favorites_count', 'free', 'gauge', 'gauge_divisor', 'gauge_pattern', 'generally_available', 'id', 'name', 'pdf_url', 'permalink', 'price', 'projects_count', 'published', 'queued_projects_count', 'rating_average', 'rating_count', 'row_gauge', 'updated_at', 'url', 'yardage', 'yardage_max', 'personal_attributes', 'sizes_available', 'product_id', 'currency_symbol', 'ravelry_download', 'download_location', 'pdf_in_library', 'volumes_in_library', 'gauge_description', 'yarn_weight_description', 'yardage_description', 'pattern_needle_sizes', 'notes_html', 'notes', 'packs', 'printings', 'yarn_weight', 'craft', 'pattern_categories', 'pattern_attributes', 'pattern_author', 'photos', 'pattern_type'])

# %%
testData
# Out:
# {'pattern': {'comments_count': 148,
#   'created_at': '2009/07/09 11:36:45 -0400',
#   'currency': None,
#   'difficulty_average': 2.332074416002238,
#   'difficulty_count': 7149,
#   'downloadable': True,
#   'favorites_count': 52672,
#   'free': True,
#   'gauge': 36.0,
#   'gauge_divisor': 4,
#   'gauge_pattern': 'stockinette stitch  ',
#   'generally_available': '2009/07/01 00:00:00 -0400',
#   'id': 130787,
#   'name': "Hermione's Everyday Socks",
#   'pdf_url': '',
#   'permalink': 'hermiones-everyday-socks',
#   'price': None,
#   'projects_count': 28663,
#   'published': '2009/07/01',
#   'queued_projects_count': 11574,
#   'rating_average': 4.628989547038327,
#   'rating_count': 7175,
#   'row_gauge': None,
#   'updated_at': '2017/01/03 08:29:11 -0500',
#   'url': 'http://dreamsinfiber.blogspot.com/2009/07/hermoines-everyday-socks-free-pattern.html#links',
#   'yardage': 350,
#   'yardage_max': 400,
#   'personal_attributes': None,
#   'sizes_available': "Women's med",
#   'product_id': 29899,
#   'currency_symbol': None,
#   'ravelry_download': True,
#   'download_location': {'type': 'ravelry',
#    'free': True,
#    'url': 'http://www.ravelry.com/dls/5092/29899'},
#   'pdf_in_library': False,
#   'volumes_in_library': None,
#   'gauge_description': '36 stitches  = 4 inches in stockinette stitch  ',
#   'yarn_weight_description': 'Fingering (14 wpi)',
#   'yardage_description': '350 - 400 yards',
#   'pattern_needle_sizes': [{'id': 1,
#     'us': '1 ',
#     'metric': 2.25,
#     'us_steel': '2',
#     'crochet': False,
#     'knitting': True,
#     'hook': 'B',
#     'name': 'US 1  - 2.25 mm',
#     'pretty_metric': '2.25'}],
#   'notes_html': '\n<p>Hermione, as described in J.K. Rowling’s Harry Potter Series, is a rather smart and practical heroine. While she can dress up with the best of them, these socks remind me of something she might wear while practicing charms or transfiguration or reading up on Arithromancy in the Gryffindor Common Room.</p>\n\n<p>This sock is knit from the cuff down and features a garter stitch edged slip stitch heel. The pattern itself is written for one size, but with a 4 stitch pattern repeat, it is easily customizable to fit whatever size one desires.</p>\n\n<p>06/27/11: PATTERN NOW AVAILABLE FOR DOWNLOAD IN GERMAN :D - <a href="http://www.ravelry.com/people/Namia">Patricia</a> was kind enough to provide a translation!</p>\n\n<p>7/30/12: Pattern now available for download in French :D Jennifer, <a href="http://www.ravelry.com/people/Nylwenn">Nylwenn</a>, was kind enough to provide a translation!</p>\n\n<p>6/24/15: Pattern now available for download in Swedish!!! Thank you Annicka, <a href="/people/MadeBySeven">MadeBySeven</a>, for providing a translation! :)</p>\n\n<p>9/23/15: Pattern now available for download in Italian :) Thank you Marina Carelli, <a href="http://www.ravelry.com/people/bricci">bricci</a> for providing a translation!!</p>\n\n<p>1/3/17: Pattern now available for download in Danish :) Thank you Marianne, <a href="/people/MarianneHo">MarianneHo</a> for providing a translation!!</p>\n\n<p><strong>NOTE: When knitting the heel flap, you begin on a WS row.</strong></p>\n',
#   'notes': 'Hermione, as described in J.K. Rowling’s Harry Potter Series, is a rather smart and practical heroine.   While she can dress up with the best of them, these socks remind me of something she might wear while practicing charms or transfiguration or reading up on Arithromancy in the Gryffindor Common Room. \r\n\r\nThis sock is knit from the cuff down and features a garter stitch edged slip stitch heel.  The pattern itself is written for one size, but with a 4 stitch pattern repeat, it is easily customizable to fit whatever size one desires. \r\n\r\n06/27/11: PATTERN NOW AVAILABLE FOR DOWNLOAD IN GERMAN :D - [Patricia][1] was kind enough to provide a translation!\r\n\r\n7/30/12:  Pattern now available for download in French :D Jennifer, [Nylwenn][2], was kind enough to provide a translation!\r\n\r\n6/24/15:  Pattern now available for download in Swedish!!!  Thank you Annicka, [MadeBySeven](/people/MadeBySeven), for providing a translation!  :)\r\n\r\n9/23/15: Pattern now available for download in Italian :)  Thank you Marina Carelli, [bricci][3] for providing a translation!!\r\n\r\n1/3/17: Pattern now available for download in Danish :)  Thank you Marianne, [MarianneHo](/people/MarianneHo) for providing a translation!!\r\n\r\n**NOTE:  When knitting the heel flap, you begin on a WS row.**\r\n\r\n\r\n  [1]: http://www.ravelry.com/people/Namia\r\n  [2]: http://www.ravelry.com/people/Nylwenn\r\n  [3]: http://www.ravelry.com/people/bricci',
#   'packs': [{'id': 7310367,
#     'primary_pack_id': None,
#     'project_id': None,
#     'skeins': None,
#     'stash_id': None,
#     'total_grams': None,
#     'total_meters': None,
#     'total_ounces': None,
#     'total_yards': None,
#     'yarn_id': None,
#     'yarn_name': None,
#     'yarn_weight': None,
#     'colorway': None,
#     'shop_name': None,
#     'yarn': None,
#     'quantity_description': None,
#     'personal_name': '',
#     'dye_lot': None,
#     'color_family_id': None,
#     'grams_per_skein': None,
#     'yards_per_skein': None,
#     'meters_per_skein': None,
#     'ounces_per_skein': None,
#     'prefer_metric_weight': True,
#     'prefer_metric_length': False,
#     'shop_id': None,
#     'thread_size': None}],
#   'printings': [{'primary_source': True,
#     'pattern_source': {'amazon_rating': None,
#      'amazon_url': None,
#      'author': 'Erica Lueder',
#      'id': 126892,
#      'list_price': None,
#      'name': 'Dreams in Fiber',
#      'out_of_print': False,
#      'patterns_count': 77,
#      'permalink': 'dreams-in-fiber-2',
#      'price': None,
#      'shelf_image_path': None,
#      'url': 'http://www.ravelry.com/stores/erica-lueder-designs'}},
#    {'primary_source': False,
#     'pattern_source': {'amazon_rating': None,
#      'amazon_url': None,
#      'author': 'Erica Lueder',
#      'id': 26083,
#      'list_price': None,
#      'name': 'Dreams in Fiber Website',
#      'out_of_print': False,
#      'patterns_count': 43,
#      'permalink': 'dreams-in-fiber-website',
#      'price': None,
#      'shelf_image_path': None,
#      'url': 'http://dreamsinfiber.blogspot.com/'}}],
#   'yarn_weight': {'crochet_gauge': '',
#    'id': 5,
#    'knit_gauge': '28',
#    'max_gauge': None,
#    'min_gauge': None,
#    'name': 'Fingering',
#    'ply': '4',
#    'wpi': '14'},
#   'craft': {'id': 2, 'name': 'Knitting', 'permalink': 'knitting'},
#   'pattern_categories': [{'id': 885,
#     'name': 'Mid-calf',
#     'permalink': 'mid-calf',
#     'parent': {'id': 354,
#      'name': 'Socks',
#      'permalink': 'socks',
#      'parent': {'id': 353,
#       'name': 'Feet / Legs',
#       'permalink': 'feet-legs',
#       'parent': {'id': 337,
#        'name': 'Accessories',
#        'permalink': 'accessories',
#        'parent': {'id': 301,
#         'name': 'Categories',
#         'permalink': 'categories'}}}}}],
#   'pattern_attributes': [{'id': 3, 'permalink': 'unisex'},
#    {'id': 8, 'permalink': 'child'},
#    {'id': 9, 'permalink': 'teen'},
#    {'id': 10, 'permalink': 'adult'},
#    {'id': 12, 'permalink': 'negative-ease'},
#    {'id': 23, 'permalink': 'top-cuff-down'},
#    {'id': 26, 'permalink': 'heel-flap'},
#    {'id': 70, 'permalink': 'textured'},
#    {'id': 205, 'permalink': 'seamless'},
#    {'id': 262, 'permalink': 'wide-toe'},
#    {'id': 267, 'permalink': 'written-pattern'},
#    {'id': 302, 'permalink': 'other-toe'}],
#   'pattern_author': {'crochet_pattern_count': 1,
#    'favorites_count': 2106,
#    'id': 14789,
#    'knitting_pattern_count': 80,
#    'name': 'Erica Lueder',
#    'patterns_count': 81,
#    'permalink': 'erica-lueder',
#    'notes': '',
#    'notes_html': None,
#    'users': [{'fave_colors': 'I enjoy all colors, but tend to gravitate towards earthier colors for projects for myself',
#      'fave_curse': 'gauge',
#      'first_name': 'Erica',
#      'id': 40158,
#      'location': 'Pleasant Hill, Iowa',
#      'username': 'Dreamsinfiber',
#      'tiny_photo_url': 'https://avatars-d.ravelrycache.com/Dreamsinfiber/20979999/hermione_ravatar_photo_tiny.jpg',
#      'small_photo_url': 'https://avatars-d.ravelrycache.com/Dreamsinfiber/20979999/hermione_ravatar_photo_small.jpg',
#      'photo_url': 'https://avatars-d.ravelrycache.com/Dreamsinfiber/20979999/hermione_ravatar_photo_large.jpg',
#      'large_photo_url': 'https://avatars-d.ravelrycache.com/Dreamsinfiber/20979999/hermione_ravatar_photo_xlarge.jpg',
#      'about_me': 'I am the mother of 2 lovely minions (the oldest is now 13) and an RN.  I spend most of my time chasing after my little ones, the free moments that I happen to stumble upon now and again are spent knitting, sewing, spinning on my wheel and/or drop spindle, weaving, and dabbling now again in crochet and embroidery.  \r\n\r\n\r\n<table style="text-align: center;"><tr><td><object type="application/x-shockwave-flash" data="http://www.etsy.com/flash/spots/etsy_mini.swf?user_id=37850&user_name=Hanlone79&item_source=shop&item_size=thumbnail&rows=3&columns=4" width="374" height="280"><param name="movie" value="http://www.etsy.com/flash/spots/etsy_mini.swf?user_id=37850&user_name=Hanlone79&item_source=shop&item_size=thumbnail&rows=3&columns=4" /></object></td></tr><tr><td><a style="text-decoration: none; font-family:Arial, Helvetica, sans-serif;color:#D35701; font-size:14px; font-weight: bold;" href="http://www.etsy.com" >Etsy</a><br/><a style="text-decoration: none; color:#D35701; font-size:10px; font-family:Arial, Helvetica, sans-serif;" href="http://www.etsy.com" >Buy Handmade</a><br/><a style="font-family:Arial, Helvetica, sans-serif;color:#0192B5; font-size: 12px; text-decoration: none;" href="http://Hanlone79.etsy.com">Hanlone79</a></td></tr></table>\r\n\r\n\r\n<img src="http://nimbo.net/quiz/gryff.gif" alt="i\'m in gryffindor!"><br>\r\n<a href="http://nimbo.net/quiz/houses.html" target="0">be sorted</a> @ <a href="http://nimbo.net" target="0">nimbo.net</a>',
#      'about_me_html': '\n<p>I am the mother of 2 lovely minions (the oldest is now 13) and an RN. I spend most of my time chasing after my little ones, the free moments that I happen to stumble upon now and again are spent knitting, sewing, spinning on my wheel and/or drop spindle, weaving, and dabbling now again in crochet and embroidery.</p>\n<table><tr><td><object width="374" height="280"><param name="movie" /></object></td></tr><tr><td><a href="http://www.etsy.com">Etsy</a><br /><a href="http://www.etsy.com">Buy Handmade</a><br /><a href="http://Hanlone79.etsy.com">Hanlone79</a></td></tr></table>\n<p><img src="https://secure-image-proxy.ravelrycache.com/?target=http%3A%2F%2Fnimbo.net%2Fquiz%2Fgryff.gif&&key=6Brt0X8UAhAhvSDODDKnWg" alt="i\'m in gryffindor!" /><br /> <br /><a href="http://nimbo.net/quiz/houses.html">be sorted</a> @ <a href="http://nimbo.net">nimbo.net</a></p>\n',
#      'pattern_author': {'favorites_count': 2106,
#       'id': 14789,
#       'name': 'Erica Lueder',
#       'patterns_count': 81,
#       'permalink': 'erica-lueder'},
#      'user_sites': [{'id': 296378,
#        'username': 'Erica.Lueder',
#        'url': 'http://www.facebook.com/Erica.Lueder',
#        'social_site': {'id': 8,
#         'name': 'Facebook',
#         'favicon_url': 'http:///images/favicons/facebook.png',
#         'active': True}},
#       {'id': 296377,
#        'username': 'www.hanlone79.etsy.com',
#        'url': 'http://www.hanlone79.etsy.com.etsy.com',
#        'social_site': {'id': 11,
#         'name': 'Etsy',
#         'favicon_url': 'http:///images/favicons/etsy.png',
#         'active': True}},
#       {'id': 296379,
#        'username': 'dreamsinfiber',
#        'url': 'http://instagram.com/dreamsinfiber',
#        'social_site': {'id': 28,
#         'name': 'Instagram',
#         'favicon_url': 'http:///images/instagram-favicon2018-1.png',
#         'active': True}}]}]},
#   'photos': [{'id': 7278181,
#     'sort_order': 1,
#     'x_offset': -8,
#     'y_offset': -35,
#     'square_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404_s.jpg',
#     'medium_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404.jpg',
#     'thumbnail_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404_t.jpg',
#     'small_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404_m.jpg',
#     'flickr_url': 'http://www.flickr.com/photos/83101710@N00/3704532404',
#     'shelved_url': None,
#     'medium2_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404.jpg',
#     'small2_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704532404/3704532404_n.jpg',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': None},
#    {'id': 42093355,
#     'sort_order': 2,
#     'x_offset': -5,
#     'y_offset': -35,
#     'square_url': 'https://images4-g.ravelrycache.com/uploads/Mayfarm/240760736/image_square.jpg',
#     'medium_url': 'https://images4-g.ravelrycache.com/uploads/Mayfarm/240760736/image_medium.jpg',
#     'thumbnail_url': 'https://images4-g.ravelrycache.com/uploads/Mayfarm/240760736/image_thumbnail.jpg',
#     'small_url': 'https://images4-g.ravelrycache.com/uploads/Mayfarm/240760736/image_small.jpg',
#     'flickr_url': None,
#     'shelved_url': 'https://images4-g.ravelrycache.com/uploads/Mayfarm/240760736/image_shelved.jpg',
#     'medium2_url': 'https://images4-f.ravelrycache.com/uploads/Mayfarm/240760736/image_medium2.jpg',
#     'small2_url': 'https://images4-g.ravelrycache.com/uploads/Mayfarm/240760736/image_small2.jpg',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': 'Mayfarm'},
#    {'id': 23554769,
#     'sort_order': 3,
#     'x_offset': -35,
#     'y_offset': -5,
#     'square_url': 'https://images4-g.ravelrycache.com/uploads/snippetsandstash/102807366/IMG_9323edit_square.jpg',
#     'medium_url': 'https://images4-f.ravelrycache.com/uploads/snippetsandstash/102807366/IMG_9323edit_medium.jpg',
#     'thumbnail_url': 'https://images4-f.ravelrycache.com/uploads/snippetsandstash/102807366/IMG_9323edit_thumbnail.jpg',
#     'small_url': 'https://images4-f.ravelrycache.com/uploads/snippetsandstash/102807366/IMG_9323edit_small.jpg',
#     'flickr_url': None,
#     'shelved_url': 'https://images4-g.ravelrycache.com/uploads/snippetsandstash/102807366/IMG_9323edit_shelved.jpg',
#     'medium2_url': 'https://images4-f.ravelrycache.com/uploads/snippetsandstash/102807366/IMG_9323edit_medium2.jpg',
#     'small2_url': 'https://images4-g.ravelrycache.com/uploads/snippetsandstash/102807366/IMG_9323edit_small2.jpg',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': 'snippetsandstash'},
#    {'id': 16251704,
#     'sort_order': 4,
#     'x_offset': -45,
#     'y_offset': -5,
#     'square_url': 'https://images4-f.ravelrycache.com/uploads/knitterjenny/56821454/P1200528_square.jpg',
#     'medium_url': 'https://images4-g.ravelrycache.com/uploads/knitterjenny/56821454/P1200528_medium.jpg',
#     'thumbnail_url': 'https://images4-f.ravelrycache.com/uploads/knitterjenny/56821454/P1200528_thumbnail.jpg',
#     'small_url': 'https://images4-g.ravelrycache.com/uploads/knitterjenny/56821454/P1200528_small.jpg',
#     'flickr_url': None,
#     'shelved_url': 'https://images4-f.ravelrycache.com/uploads/knitterjenny/56821454/P1200528_shelved.jpg',
#     'medium2_url': 'https://images4-g.ravelrycache.com/uploads/knitterjenny/56821454/P1200528_medium2.jpg',
#     'small2_url': 'https://images4-f.ravelrycache.com/uploads/knitterjenny/56821454/P1200528_small2.jpg',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': 'knitterjenny'},
#    {'id': 9595747,
#     'sort_order': 5,
#     'x_offset': -38,
#     'y_offset': -1,
#     'square_url': 'https://images4-f.ravelrycache.com/uploads/azgal/20122864/IMG_1790_square.JPG',
#     'medium_url': 'https://images4-g.ravelrycache.com/uploads/azgal/20122864/IMG_1790_medium.JPG',
#     'thumbnail_url': 'https://images4-f.ravelrycache.com/uploads/azgal/20122864/IMG_1790_thumbnail.JPG',
#     'small_url': 'https://images4-g.ravelrycache.com/uploads/azgal/20122864/IMG_1790_small.JPG',
#     'flickr_url': None,
#     'shelved_url': 'https://images4-f.ravelrycache.com/uploads/azgal/20122864/IMG_1790_shelved.JPG',
#     'medium2_url': 'https://images4-g.ravelrycache.com/uploads/azgal/20122864/IMG_1790_medium2.JPG',
#     'small2_url': 'https://images4-f.ravelrycache.com/uploads/azgal/20122864/IMG_1790_small2.JPG',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': 'Carli Longpre'},
#    {'id': 26454147,
#     'sort_order': 6,
#     'x_offset': -6,
#     'y_offset': -82,
#     'square_url': 'https://images4-f.ravelrycache.com/uploads/kelly-ann/122798193/hermione2_square.jpg',
#     'medium_url': 'https://images4-g.ravelrycache.com/uploads/kelly-ann/122798193/hermione2_medium.jpg',
#     'thumbnail_url': 'https://images4-g.ravelrycache.com/uploads/kelly-ann/122798193/hermione2_thumbnail.jpg',
#     'small_url': 'https://images4-f.ravelrycache.com/uploads/kelly-ann/122798193/hermione2_small_best_fit.jpg',
#     'flickr_url': None,
#     'shelved_url': 'https://images4-f.ravelrycache.com/uploads/kelly-ann/122798193/hermione2_shelved.jpg',
#     'medium2_url': 'https://images4-g.ravelrycache.com/uploads/kelly-ann/122798193/hermione2_medium2.jpg',
#     'small2_url': 'https://images4-f.ravelrycache.com/uploads/kelly-ann/122798193/hermione2_small2.jpg',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': 'kelly-ann'},
#    {'id': 8094774,
#     'sort_order': 7,
#     'x_offset': -6,
#     'y_offset': -12,
#     'square_url': 'https://images4-g.ravelrycache.com/flickr/3/9/0/3903419154/3903419154_s.jpg',
#     'medium_url': 'https://images4-g.ravelrycache.com/flickr/3/9/0/3903419154/3903419154.jpg',
#     'thumbnail_url': 'https://images4-g.ravelrycache.com/flickr/3/9/0/3903419154/3903419154_t.jpg',
#     'small_url': 'https://images4-g.ravelrycache.com/flickr/3/9/0/3903419154/3903419154_m.jpg',
#     'flickr_url': None,
#     'shelved_url': None,
#     'medium2_url': 'https://images4-g.ravelrycache.com/flickr/3/9/0/3903419154/3903419154.jpg',
#     'small2_url': 'https://images4-g.ravelrycache.com/flickr/3/9/0/3903419154/3903419154_n.jpg',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': None},
#    {'id': 8222214,
#     'sort_order': 8,
#     'x_offset': -3,
#     'y_offset': -14,
#     'square_url': 'https://images4-g.ravelrycache.com/flickr/3/9/6/3963272652/3963272652_s.jpg',
#     'medium_url': 'https://images4-g.ravelrycache.com/flickr/3/9/6/3963272652/3963272652.jpg',
#     'thumbnail_url': 'https://images4-g.ravelrycache.com/flickr/3/9/6/3963272652/3963272652_t.jpg',
#     'small_url': 'https://images4-g.ravelrycache.com/flickr/3/9/6/3963272652/3963272652_m.jpg',
#     'flickr_url': 'http://www.flickr.com/photos/49745078@N00/3963272652',
#     'shelved_url': None,
#     'medium2_url': 'https://images4-g.ravelrycache.com/flickr/3/9/6/3963272652/3963272652.jpg',
#     'small2_url': 'https://images4-g.ravelrycache.com/flickr/3/9/6/3963272652/3963272652_n.jpg',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': None},
#    {'id': 7612612,
#     'sort_order': 9,
#     'x_offset': 0,
#     'y_offset': 0,
#     'square_url': 'https://images4-f.ravelrycache.com/uploads/starlite75/12358689/P8080046_square.JPG',
#     'medium_url': 'https://images4-f.ravelrycache.com/uploads/starlite75/12358689/P8080046_medium.JPG',
#     'thumbnail_url': 'https://images4-g.ravelrycache.com/uploads/starlite75/12358689/P8080046_thumbnail.JPG',
#     'small_url': 'https://images4-f.ravelrycache.com/uploads/starlite75/12358689/P8080046_small.JPG',
#     'flickr_url': None,
#     'shelved_url': 'https://images4-g.ravelrycache.com/uploads/starlite75/12358689/P8080046_shelved.JPG',
#     'medium2_url': 'https://images4-g.ravelrycache.com/uploads/starlite75/12358689/P8080046_medium2.JPG',
#     'small2_url': 'https://images4-f.ravelrycache.com/uploads/starlite75/12358689/P8080046_small2.JPG',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': 'starlite75'},
#    {'id': 7278182,
#     'sort_order': 10,
#     'x_offset': -50,
#     'y_offset': -2,
#     'square_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704530820/3704530820_s.jpg',
#     'medium_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704530820/3704530820.jpg',
#     'thumbnail_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704530820/3704530820_t.jpg',
#     'small_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704530820/3704530820_m.jpg',
#     'flickr_url': 'http://www.flickr.com/photos/83101710@N00/3704530820',
#     'shelved_url': None,
#     'medium2_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704530820/3704530820.jpg',
#     'small2_url': 'https://images4-g.ravelrycache.com/flickr/3/7/0/3704530820/3704530820_n.jpg',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': None},
#    {'id': 7612240,
#     'sort_order': 11,
#     'x_offset': -11,
#     'y_offset': -46,
#     'square_url': 'https://images4-f.ravelrycache.com/uploads/akurlykale/12361127/SANY0002_square.JPG',
#     'medium_url': 'https://images4-f.ravelrycache.com/uploads/akurlykale/12361127/SANY0002_medium.JPG',
#     'thumbnail_url': 'https://images4-f.ravelrycache.com/uploads/akurlykale/12361127/SANY0002_thumbnail.JPG',
#     'small_url': 'https://images4-f.ravelrycache.com/uploads/akurlykale/12361127/SANY0002_small.JPG',
#     'flickr_url': None,
#     'shelved_url': 'https://images4-f.ravelrycache.com/uploads/akurlykale/12361127/SANY0002_shelved.JPG',
#     'medium2_url': 'https://images4-f.ravelrycache.com/uploads/akurlykale/12361127/SANY0002_medium2.JPG',
#     'small2_url': 'https://images4-f.ravelrycache.com/uploads/akurlykale/12361127/SANY0002_small2.JPG',
#     'caption': None,
#     'caption_html': None,
#     'copyright_holder': 'akurlykale'}],
#   'pattern_type': {'clothing': True,
#    'id': 2,
#    'name': 'Socks',
#    'permalink': 'socks'}}}

# %% [markdown]
# Our first call to the Ravelry API snags us the top 1000 patterns based on popularity. This is great, and if nothing else grabs the pattern ID for each of these patterns. We can use that ID to call the API again and get more detailed information about each pattern, which is the real information we want at this point.
#
# Looking over the keys, these are the ones that may be the most interesting for analysis purposes.
# - difficulty_average
# - rating_average
# - projects_count
# - downloadable
# - free
# - published
# - price
# - yardage
# - yardage_max
# - yarn_weight > name
# - craft > name
# - pattern_type > name
#
# These are a few traits that I feel are consistent enough across Ravelry's pattern offerings to use for various analysis. We could find that the most popular patterns end up having a low difficulty and a low maximum yardage to complete the project, or most commonly use a particular weight of yarn. Or even something as simple as the fact that they are free and available as a download directly from Ravelry, which is simply a matter of convenience.
#
# Next, let's initialize the list containers and confirm the indexing for each value. We'll follow that up by writing the loops that will snag our data.

# %%
id_ls = []
difficulty_average_ls = []
rating_average_ls = []
projects_count_ls = []
downloadable_ls = []
free_ls = []
published_ls = []
price_ls = []
yardage_ls = []
yardage_max_ls = []
yarn_weight_ls = []
craft_ls = []
pattern_type_ls = []

# %%
patternset1 = patternData1['patterns']

# %%
for pattern in patternset1:
    patternID = pattern['id']
    loopURL = f"https://api.ravelry.com/patterns/{patternID}.json"
    loop_response = requests.get(loopURL, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))
    pattern_loop = loop_response.json()
    
    try: difficulty_average = pattern_loop['pattern']['difficulty_average']
    except: difficulty_average = None
        
    try: rating_average = pattern_loop['pattern']['rating_average']
    except: rating_average = None
        
    try: projects_count = pattern_loop['pattern']['projects_count']
    except: projects_count = None
        
    try: downloadable = pattern_loop['pattern']['downloadable']
    except: downloadable = None
        
    try: free = pattern_loop['pattern']['free']
    except: free = None
        
    try: published = pattern_loop['pattern']['published']
    except: published = None
        
    try: price = pattern_loop['pattern']['price']
    except: price = None
        
    try: yardage = pattern_loop['pattern']['yardage']
    except: yardage = None
        
    try: yardage_max = pattern_loop['pattern']['yardage_max']
    except: yardage_max = None
        
    try: yarn_weight = pattern_loop['pattern']['yarn_weight']['name']
    except: yarn_weight = None
        
    try: craft = pattern_loop['pattern']['craft']['name']
    except: craft = None
        
    try: pattern_type = pattern_loop['pattern']['pattern_type']['name']
    except: pattern_type = None
    
    id_ls.append(patternID)
    difficulty_average_ls.append(difficulty_average)
    rating_average_ls.append(rating_average)
    projects_count_ls.append(projects_count)
    downloadable_ls.append(downloadable)
    free_ls.append(free)
    published_ls.append(published)
    price_ls.append(price)
    yardage_ls.append(yardage)
    yardage_max_ls.append(yardage_max)
    yarn_weight_ls.append(yarn_weight)
    craft_ls.append(craft)
    pattern_type_ls.append(pattern_type)

# %%
print(len(id_ls))
print(len(difficulty_average_ls))
print(len(rating_average_ls))
print(len(projects_count_ls))
print(len(downloadable_ls))
print(len(free_ls))
print(len(published_ls))
print(len(price_ls))
print(len(yardage_ls))
print(len(yardage_max_ls))
print(len(yarn_weight_ls))
print(len(craft_ls))
print(len(pattern_type_ls))
# Out:
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000
# 2000

# %%
patternset2 = patternData2['patterns']
patternset3 = patternData3['patterns']
patternset4 = patternData4['patterns']
patternset5 = patternData5['patterns']

# %%
for pattern in patternset2:
    patternID = pattern['id']
    loopURL = f"https://api.ravelry.com/patterns/{patternID}.json"
    loop_response = requests.get(loopURL, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))
    pattern_loop = loop_response.json()
    
    try: difficulty_average = pattern_loop['pattern']['difficulty_average']
    except: difficulty_average = None
        
    try: rating_average = pattern_loop['pattern']['rating_average']
    except: rating_average = None
        
    try: projects_count = pattern_loop['pattern']['projects_count']
    except: projects_count = None
        
    try: downloadable = pattern_loop['pattern']['downloadable']
    except: downloadable = None
        
    try: free = pattern_loop['pattern']['free']
    except: free = None
        
    try: published = pattern_loop['pattern']['published']
    except: published = None
        
    try: price = pattern_loop['pattern']['price']
    except: price = None
        
    try: yardage = pattern_loop['pattern']['yardage']
    except: yardage = None
        
    try: yardage_max = pattern_loop['pattern']['yardage_max']
    except: yardage_max = None
        
    try: yarn_weight = pattern_loop['pattern']['yarn_weight']['name']
    except: yarn_weight = None
        
    try: craft = pattern_loop['pattern']['craft']['name']
    except: craft = None
        
    try: pattern_type = pattern_loop['pattern']['pattern_type']['name']
    except: pattern_type = None
    
    id_ls.append(patternID)
    difficulty_average_ls.append(difficulty_average)
    rating_average_ls.append(rating_average)
    projects_count_ls.append(projects_count)
    downloadable_ls.append(downloadable)
    free_ls.append(free)
    published_ls.append(published)
    price_ls.append(price)
    yardage_ls.append(yardage)
    yardage_max_ls.append(yardage_max)
    yarn_weight_ls.append(yarn_weight)
    craft_ls.append(craft)
    pattern_type_ls.append(pattern_type)

# %%
for pattern in patternset3:
    patternID = pattern['id']
    loopURL = f"https://api.ravelry.com/patterns/{patternID}.json"
    loop_response = requests.get(loopURL, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))
    pattern_loop = loop_response.json()
    
    try: difficulty_average = pattern_loop['pattern']['difficulty_average']
    except: difficulty_average = None
        
    try: rating_average = pattern_loop['pattern']['rating_average']
    except: rating_average = None
        
    try: projects_count = pattern_loop['pattern']['projects_count']
    except: projects_count = None
        
    try: downloadable = pattern_loop['pattern']['downloadable']
    except: downloadable = None
        
    try: free = pattern_loop['pattern']['free']
    except: free = None
        
    try: published = pattern_loop['pattern']['published']
    except: published = None
        
    try: price = pattern_loop['pattern']['price']
    except: price = None
        
    try: yardage = pattern_loop['pattern']['yardage']
    except: yardage = None
        
    try: yardage_max = pattern_loop['pattern']['yardage_max']
    except: yardage_max = None
        
    try: yarn_weight = pattern_loop['pattern']['yarn_weight']['name']
    except: yarn_weight = None
        
    try: craft = pattern_loop['pattern']['craft']['name']
    except: craft = None
        
    try: pattern_type = pattern_loop['pattern']['pattern_type']['name']
    except: pattern_type = None
    
    id_ls.append(patternID)
    difficulty_average_ls.append(difficulty_average)
    rating_average_ls.append(rating_average)
    projects_count_ls.append(projects_count)
    downloadable_ls.append(downloadable)
    free_ls.append(free)
    published_ls.append(published)
    price_ls.append(price)
    yardage_ls.append(yardage)
    yardage_max_ls.append(yardage_max)
    yarn_weight_ls.append(yarn_weight)
    craft_ls.append(craft)
    pattern_type_ls.append(pattern_type)

# %%
for pattern in patternset4:
    patternID = pattern['id']
    loopURL = f"https://api.ravelry.com/patterns/{patternID}.json"
    loop_response = requests.get(loopURL, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))
    pattern_loop = loop_response.json()
    
    try: difficulty_average = pattern_loop['pattern']['difficulty_average']
    except: difficulty_average = None
        
    try: rating_average = pattern_loop['pattern']['rating_average']
    except: rating_average = None
        
    try: projects_count = pattern_loop['pattern']['projects_count']
    except: projects_count = None
        
    try: downloadable = pattern_loop['pattern']['downloadable']
    except: downloadable = None
        
    try: free = pattern_loop['pattern']['free']
    except: free = None
        
    try: published = pattern_loop['pattern']['published']
    except: published = None
        
    try: price = pattern_loop['pattern']['price']
    except: price = None
        
    try: yardage = pattern_loop['pattern']['yardage']
    except: yardage = None
        
    try: yardage_max = pattern_loop['pattern']['yardage_max']
    except: yardage_max = None
        
    try: yarn_weight = pattern_loop['pattern']['yarn_weight']['name']
    except: yarn_weight = None
        
    try: craft = pattern_loop['pattern']['craft']['name']
    except: craft = None
        
    try: pattern_type = pattern_loop['pattern']['pattern_type']['name']
    except: pattern_type = None
    
    id_ls.append(patternID)
    difficulty_average_ls.append(difficulty_average)
    rating_average_ls.append(rating_average)
    projects_count_ls.append(projects_count)
    downloadable_ls.append(downloadable)
    free_ls.append(free)
    published_ls.append(published)
    price_ls.append(price)
    yardage_ls.append(yardage)
    yardage_max_ls.append(yardage_max)
    yarn_weight_ls.append(yarn_weight)
    craft_ls.append(craft)
    pattern_type_ls.append(pattern_type)

# %%
for pattern in patternset5:
    patternID = pattern['id']
    loopURL = f"https://api.ravelry.com/patterns/{patternID}.json"
    loop_response = requests.get(loopURL, auth=(RAVELRY_USERNAME, RAVELRY_PASSWORD))
    pattern_loop = loop_response.json()
    
    try: difficulty_average = pattern_loop['pattern']['difficulty_average']
    except: difficulty_average = None
        
    try: rating_average = pattern_loop['pattern']['rating_average']
    except: rating_average = None
        
    try: projects_count = pattern_loop['pattern']['projects_count']
    except: projects_count = None
        
    try: downloadable = pattern_loop['pattern']['downloadable']
    except: downloadable = None
        
    try: free = pattern_loop['pattern']['free']
    except: free = None
        
    try: published = pattern_loop['pattern']['published']
    except: published = None
        
    try: price = pattern_loop['pattern']['price']
    except: price = None
        
    try: yardage = pattern_loop['pattern']['yardage']
    except: yardage = None
        
    try: yardage_max = pattern_loop['pattern']['yardage_max']
    except: yardage_max = None
        
    try: yarn_weight = pattern_loop['pattern']['yarn_weight']['name']
    except: yarn_weight = None
        
    try: craft = pattern_loop['pattern']['craft']['name']
    except: craft = None
        
    try: pattern_type = pattern_loop['pattern']['pattern_type']['name']
    except: pattern_type = None
    
    id_ls.append(patternID)
    difficulty_average_ls.append(difficulty_average)
    rating_average_ls.append(rating_average)
    projects_count_ls.append(projects_count)
    downloadable_ls.append(downloadable)
    free_ls.append(free)
    published_ls.append(published)
    price_ls.append(price)
    yardage_ls.append(yardage)
    yardage_max_ls.append(yardage_max)
    yarn_weight_ls.append(yarn_weight)
    craft_ls.append(craft)
    pattern_type_ls.append(pattern_type)

# %%
print(len(id_ls))
print(len(difficulty_average_ls))
print(len(rating_average_ls))
print(len(projects_count_ls))
print(len(downloadable_ls))
print(len(free_ls))
print(len(published_ls))
print(len(price_ls))
print(len(yardage_ls))
print(len(yardage_max_ls))
print(len(yarn_weight_ls))
print(len(craft_ls))
print(len(pattern_type_ls))
# Out:
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000

# %%
TopPatternList = list(zip(id_ls, difficulty_average_ls, rating_average_ls, projects_count_ls,
                         downloadable_ls, free_ls, published_ls, price_ls, yardage_ls,
                         yardage_max_ls, yarn_weight_ls, craft_ls, pattern_type_ls))

colnames = ['Pattern ID', 'Average Difficulty', 'Average Rating', 'Total Projects', 'Downloadable', 'Free',
           'Publish Date','Price', 'Min Yardage', 'Max Yardage', 'Yarn Weight', 'Craft', 'Category']

# %%
import pandas as pd

df = pd.DataFrame(TopPatternList, columns=colnames)

df.head(10)
# Out:
#    Pattern ID  Average Difficulty  Average Rating  Total Projects  \
# 0      130787            2.332074        4.628990           28663
# 1      418518            2.534649        4.804386           20206
# 2      426231            1.639235        4.711647           20770
# 3      443533            2.297305        4.726276           14761
# 4      124400            1.506778        4.639974           21161
# 5      709323            1.886782        4.795863            8181
# 6      788421            2.909037        4.750430            6244
# 7      580119            2.093617        4.781236           10400
# 8      315418            2.155676        4.647897           13695
# 9      588220            2.288232        4.606033           11319
#
#    Downloadable   Free Publish Date  Price  Min Yardage  Max Yardage  \
# 0          True   True   2009/07/01    NaN        350.0        400.0
# 1          True  False   2013/07/01    1.0          NaN          NaN
# 2          True   True   2013/07/01    NaN         70.0        170.0
# 3          True   True   2013/10/01    NaN        280.0       1800.0
# 4          True   True   2009/05/01    NaN        155.0        415.0
# 5          True   True   2016/12/01    NaN         70.0        300.0
# 6          True  False   2017/11/01    8.0        915.0       1919.0
# 7          True   True   2015/05/01    NaN        200.0        350.0
# 8          True   True         None    NaN        350.0        400.0
# 9          True   True   2015/06/01    NaN        380.0        420.0
#
#        Yarn Weight     Craft        Category
# 0        Fingering  Knitting           Socks
# 1        Fingering  Knitting           Other
# 2          Worsted  Knitting           Child
# 3             Aran  Knitting           Child
# 4        Fingering  Knitting           Child
# 5        Any gauge  Knitting  Mittens/Gloves
# 6          Worsted  Knitting        Pullover
# 7        Fingering  Knitting           Socks
# 8        Fingering  Knitting           Socks
# 9  Light Fingering  Knitting      Shawl/Wrap

# %%
df['Price'].fillna(0, inplace=True)
df['Min Yardage'].fillna(0, inplace=True)
df['Max Yardage'].fillna(0, inplace=True)
df.head()
# Out:
#    Pattern ID  Average Difficulty  Average Rating  Total Projects  \
# 0      130787            2.332074        4.628990           28663
# 1      418518            2.534649        4.804386           20206
# 2      426231            1.639235        4.711647           20770
# 3      443533            2.297305        4.726276           14761
# 4      124400            1.506778        4.639974           21161
#
#    Downloadable   Free Publish Date  Price  Min Yardage  Max Yardage  \
# 0          True   True   2009/07/01    0.0        350.0        400.0
# 1          True  False   2013/07/01    1.0          0.0          0.0
# 2          True   True   2013/07/01    0.0         70.0        170.0
# 3          True   True   2013/10/01    0.0        280.0       1800.0
# 4          True   True   2009/05/01    0.0        155.0        415.0
#
#   Yarn Weight     Craft Category
# 0   Fingering  Knitting    Socks
# 1   Fingering  Knitting    Other
# 2     Worsted  Knitting    Child
# 3        Aran  Knitting    Child
# 4   Fingering  Knitting    Child

# %%
df.isnull().sum()
# Out:
# Pattern ID              0
# Average Difficulty      0
# Average Rating          0
# Total Projects          0
# Downloadable            0
# Free                    0
# Publish Date          754
# Price                   0
# Min Yardage             0
# Max Yardage             0
# Yarn Weight           176
# Craft                   0
# Category                0
# dtype: int64

# %%
df['Yarn Weight'].fillna('None Specified', inplace=True)

# %%
df.isnull().sum()
# Out:
# Pattern ID              0
# Average Difficulty      0
# Average Rating          0
# Total Projects          0
# Downloadable            0
# Free                    0
# Publish Date          754
# Price                   0
# Min Yardage             0
# Max Yardage             0
# Yarn Weight             0
# Craft                   0
# Category                0
# dtype: int64

# %%
df.to_csv('TopRavelryPatternList.csv', index=False, header=True)

# %% [markdown]
# I've opted to accept the null values for Publish Date, as these won't make or break any algorithms moving forward; nulls can simply be ignored as-needed to preserve the other entries should we need to do analysis based on date.
#
# But there we have it. All 10000 lines have been sent to a .csv for easy use later in Tableau for presentation visuals, or to import for further analysis.
